# %%
pip install scipy
# Out:
# Requirement already satisfied: scipy in c:\users\97254\desktop\final-project\.venv\lib\site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in c:\users\97254\desktop\final-project\.venv\lib\site-packages (from scipy) (2.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# c:\Users\97254\Desktop\Final-Project\.venv\Scripts\python.exe
# 3.13.9 (tags/v3.13.9:8183fa5, Oct 14 2025, 14:09:13) [MSC v.1944 64 bit (AMD64)]

# %%
print("start")

import numpy as np
print("numpy ok")

import pandas as pd
print("pandas ok")

from scipy import stats
print("scipy ok")

import matplotlib.pyplot as plt
print("matplotlib ok")

import seaborn as sns
print("seaborn ok")

import statsmodels.api as sm
print("statsmodels ok")

from statsmodels.formula.api import ols
print("ols ok")

print("all ok")
# Out:
# start
# numpy ok
# pandas ok
# scipy ok
# matplotlib ok
# seaborn ok
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 18
#      15 import seaborn as sns
#      16 print("seaborn ok")
# ---> 18 import statsmodels.api as sm
#      19 print("statsmodels ok")
#      21 from statsmodels.formula.api import ols
#
# ModuleNotFoundError: No module named 'statsmodels'
